# %% [markdown]
# # Module 04 — Exercise: UAV Regulatory Framework
#
# **DIGIHAZ PhD Course** | Disaster Risk Reduction
#
# ---

# %% [markdown]
# ## Student Information
#
# - **Name:**
# - **Student ID:**
# - **Date:**

# %%
# Setup
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Your Work
#
# *Complete the tasks below.*

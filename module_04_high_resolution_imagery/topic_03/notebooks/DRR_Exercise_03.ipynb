# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/DIGIHAZ-DRR/drr-course-materials/blob/main/module_04_high-resolution-imagery-for-disaster-mapping/topic_03/DRR_exercise_03.ipynb)
#
#
# # Module: High Resolution Imagery for Disaster Mapping
#
# ## Topic 3: Design and Development of UAV-Based Monitoring Frameworks
#
# * Author: Assistant Professor Dr. Giorgos SFIKAS
# * Date: April 2026
# ---

# %% [markdown]
# ## Overview of exercise
#
# In the exercise for this topic, you will be tasked to write code that opens a GeoJSON file.
#
#   1. Use Regular expressions, Python JSON libaries or other means to write a Python class to create basic functionality that manipulates a GeoJSON file.
#   2. The class should have at least methods to: read a GeoJSON from a file, write the GeoJSON to the file, create a new GeoJSON. Optionally include methods to manipulate the GeoJSON contents.
#   3. Use the sample found at https://gist.githubusercontent.com/wavded/1200773/raw/e122cf709898c09758aecfef349964a8d73a83f3/sample.json for your experiments.
#   4. Use your code to create a new GeoJSON that includes a polygon delineating your home country. Visualize it (e.g. by opening it via the github interface).

# %%
# Use Regular expressions, Python JSON libaries or other means to 
# write a Python class to create basic functionality that manipulates a GeoJSON file.
#
# TODO

# %%
# The class should have at least methods to: read a GeoJSON from a file, 
# write the GeoJSON to the file, create a new GeoJSON. 
# Optionally include methods to manipulate the GeoJSON contents.
#
# TODO

# %%
# Experiment using the sample found at
# https://gist.githubusercontent.com/wavded/1200773/raw/e122cf709898c09758aecfef349964a8d73a83f3/sample.json 
#
# TODO

# %%
# Use your code to create a new GeoJSON that includes a polygon 
# delineating your home country. Visualize it (e.g. by opening it via the github interface).
#
# TODO

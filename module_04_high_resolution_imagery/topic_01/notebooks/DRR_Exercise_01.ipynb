# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/DIGIHAZ-DRR/drr-course-materials/blob/main/module_04_high-resolution-imagery-for-disaster-mapping/topic_01/DRR_exercise_01.ipynb)
#
#
# # Module: High Resolution Imagery for Disaster Mapping
#
# ## Topic 1: Unmanned Systems & image processing Basics (UNIWA - UC)
#
# * Author: Assistant Professor Dr. Giorgos SFIKAS
# * Date: April 2026
# ---

# %% [markdown]
# ## Overview of exercise
#
# In this exercise you will experiment with a simple digital image processing pipeline.
#
# Steps:
# * 1.Load the digital image.
# * 2.Produce "crops" of the input image and save them as separate images. Center your crops on objects of interest in the original image.
# * 3.Compute histograms for the original image and the cropped images.
# * 4.Implement a thresholding point processing pipeline. Experiment with different choices of thresholds.
#
#
# ## Tips
#
# * You can, and should, take your time to review the documentation of Python and the basic libraries for digital imaging, including numpy, PIL, matplotlib.
#   * https://docs.python.org/
#   * https://numpy.org/doc/
#   * https://matplotlib.org/stable/index.html
# * The repository https://github.com/dip-course/crashcourse-python-numpy-scipy/ contains a useful resumé of all you will require for this exercise, and more.

# %%
# Load standard imaging libraries in Python
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
# Load a test image
import skimage.data as fixtures
A = fixtures.camera()
# Visualize it
plt.imshow(A, cmap="gray")
plt.show()

# %%
# Example:
# We can manipulate the image content by manipulating the numpy array
# For example:
A2 = np.copy(A)
A2[300:400, 300:400] = 0
plt.imshow(A2, cmap="gray")
plt.show()

# %%
# Load a gray-scale image from the provided png file ('monemvasia1955.png')
#
# TODO
#

# %%
# Examine the image using the 'print' image.
#
# TODO
#

# %%
# Visualize the image using the 'imshow' command.
#
# TODO
#

# %%
# Implement a thresholding method. Experiment with different thresholds.
#
# TODO
#

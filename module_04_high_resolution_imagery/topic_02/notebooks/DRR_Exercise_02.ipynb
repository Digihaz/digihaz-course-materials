# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/DIGIHAZ-DRR/drr-course-materials/blob/main/module_04_high-resolution-imagery-for-disaster-mapping/topic_02/DRR_exercise_02.ipynb)
#
#
# # Module: High Resolution Imagery for Disaster Mapping
#
# ## Topic 2: Drone Imagery Processing and Photogrammetric Workflows
#
# * Author: Assistant Professor Dr. Giorgos SFIKAS
# * Date: April 2026
# ---

# %% [markdown]
# ## Overview of exercise
#
# In this exercise you will experiment with the photogrammetric pipeline through the powerful open-source OpenDroneMap software.
#
# Steps:
# * 1. Install ODM after installing prerequisite software (git, docker)
# * 2. Setup and load one of the designated datasets to ODM.
# * 3. Inspect the various photogrammetric products.

# %%
# Install git following the instructions in https://git-scm.com/
# Here we will use git to download data; in general,
# knowing how to use git is a very useful skill in all disciplines that are related to software.
# Check that git is up and running by typing in the command line:
#
# git
# git status 
#

# %%
# Download the "ODM MYGLA" dataset using git.
# Use the command-line interface:
#
# TODO
#
# git clone git@github.com:merkato/odm_mygla_dataset.git

# %%
# Install Docker. This is another useful piece of software, that handles
# software dependencies gracefully, without the use of complicated "virtual environments".
# Check that docker is up and running by typing in the command line:
#
# docker

# TODO
# docker run -ti --rm -v /my/project:/datasets/code opendronemap/odm --project-path /datasets

# %%
# Download the "Open Drone Map" photogrammetric suite using docker.
# Use the command-line interface:
#
# TODO
#
# docker pull opendronemap/odm

# %%
# Run ODM using docker:
#
# TODO
#
# (Windows)
# docker run -ti --rm -v c:/Users/youruser/datasets:/datasets opendronemap/odm --project-path /datasets project
#
# (Linux)
# docker run -ti --rm -v /home/youruser/datasets:/datasets opendronemap/odm --project-path /datasets project

# %%
# The products will be organized as follows:
# |-- images/
#     |-- img-1234.jpg
#     |-- ...
# |-- opensfm/
#     |-- see mapillary/opensfm repository for more info
# |-- odm_meshing/
#     |-- odm_mesh.ply                    # A 3D mesh
# |-- odm_texturing/
#     |-- odm_textured_model.obj          # Textured mesh
#     |-- odm_textured_model_geo.obj      # Georeferenced textured mesh
# |-- odm_georeferencing/
#     |-- odm_georeferenced_model.laz     # LAZ format point cloud
# |-- odm_orthophoto/
# |-- odm_orthophoto.tif              # Orthophoto GeoTiff

# %%
# Discussion and further optional actions:
#
# 1.Open the "Orthophoto" in folder "odm_orthophoto". In what respects is this different than a "standard" photo?
# 2.Examine the resulting products of the pipeline using QGIS (GeoTIFF files), CloudCompare (laz file), 3D model/textured mesh (OBJ file).
# 3.Try other datasets, or create your own and run the pipeline on your inputs.

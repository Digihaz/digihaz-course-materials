# %% [markdown]
# # Module 09 — Exercise: Seismic catalogue preparation (I)
#
# **DIGIHAZ PhD Course** | Disaster Risk Reduction
#
# ---

# %% [markdown]
# ## Student Information
#
# - **Name:**
# - **Student ID:**
# - **Date:**

# %%
pip install pandas

# %%
pip install matplotlib

# %%
# Setup
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Your Work
#
# *Complete the tasks below.*

# %% [markdown]
# ### 1) Load the catalogue and remove any duplicates that may exist in the catalogue.
#
# Load the catalogue using the appropiate separators and options in pandas in order to create a dataframe with the name 'data'. Be careful with the withespaces inside the cells, there is an option in pandas when loading the file to handle them. Create an ID for each event that can be used to identify identical events and then use it to remove any duplicated event. **How many events were duplicated? Can you display them using the 'display' function?**

# %% [markdown]
# ### 2) Convert the roman numerals that appear in the intensity field into decimal numbers.

# %% [markdown]
# ### 3) Convert all the magnitudes and intensities into moment magnitude (Mw) whenever possible.
#
# For this task, recall the table with the conversion equations:
#
# In the case of Spain, in the latest Seismic Hazard Map update (IGN-UPM Working Group, 2013), four equations were defined to convert different magnitude and intensity scales into moment magnitude (Mw):
#
# |y = a + b x | Range | Magnitude type |
# | :--- | :--- | :---:|
# | $M_w$ = 1.6560 + 0.545 $I_{max}$ | 3.0 - 9.5 | 1 |
# | $M_w$ = 0.2900 + 0.973 $m_{bLg}$ | 3.1 - 7.3 | 2 |
# | $M_w$ = -1.528 + 1.213 $m_b$     | 3.7 - 6.3 | 3 |
# | $M_w$ = 0.6760 + 0.836 $m_{bLg}$ | 3.0 - 5.1 | 4 |
#
# Remember that before applying the conversion we must locate which events have no magnitude type nor intensity/magnitude values.
#
# Once applied, filter out all the events for which the mw could not be computed. **How many events remain in the catalogue?**

# %% [markdown]
# ### 4) Compute the decimal year of every event in the catalogue.
#
# Use the matplotlib library to plot the Moment magnitude (Mw) (y-axis) vs Decimal year (x-axis). **Comment on the characteristics of the catalogue over time and any other aspect of interest.**

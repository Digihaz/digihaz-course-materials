# %% [markdown]
# # Module 09 — Exercise: Seismic catalogue preparation
#
# **DIGIHAZ PhD Course** | Disaster Risk Reduction
#
# ---

# %% [markdown]
# ## Student Information
#
# - **Name:**
# - **Student ID:**
# - **Date:**

# %%
pip install pandas

# %%
pip install matplotlib

# %%
# Setup
import pandas as pd                   
import numpy as np                     
import matplotlib.pyplot as plt        
import math

# %% [markdown]
# ## Your Work
#
# *Complete the tasks below.*

# %% [markdown]
# ### 1) Load the catalogue you obtained as a result of the first exercise of the module 09 topic 02 using pandas.
#
# Store it in a variable called data and check that all the required fields are inside the DataFrame (ID/event, longitude, latitude, depth, mw, date, time and decimal year)

# %% [markdown]
# ### 2) Plot the time series of the catalogue (Mw vs time) and the frequency-energy distribution (inverse cumulative distribution of the moment magnitudes).
#
# With these plots it should be possible to assess whether a declustering procedure is needed or not. Other possible plots are the longitude vs latitude (to see spatial clustering) and also longitude vs decimal year and latitude vs decimal year.

# %% [markdown]
# ### 3) Compute the seismic parameters (G-R law) by first obtaining the completeness magnitude.

# %% [markdown]
# ### 4) Decluster the catalogue using two of the proposed windowed methods (G-K, U or G).
#
# In the following table, the equations used for the definition of the spatial windows and time windows of the different window declustering methods can be found. In order to use a different declustering method, the only requierement is to modify the spatial and time window functions seen in the previous lecture:
#
# |Name | Spatial window | Time window |
# | :--- | :---: | :---:|
# | Gardner-Knopoff (Mw < 6.5) | $10^{0.1238\cdot Mw + 0.983}$ | $\frac{10^{0.5409 \cdot Mw - 0.547}}{days}$ |
# | Gardner-Knopoff (Mw ≥ 6.5) | $10^{0.1238\cdot Mw + 0.983}$ | $\frac{10^{0.032 \cdot Mw + 2.7389}}{days}$ |
# | Uhrhammer | $e^{-1.024 + 0.804 \cdot Mw}$ | $\frac{e^{-2.87 + 1.235 \cdot Mw}}{days}$ |
# | Gruenthal (Mw < 6.5) | $e^{1.77 + \sqrt{0.037 + 1.02 \cdot Mw}}$ | $abs(\frac{e^{-3.95 + \sqrt{0.62 + 17.32 \cdot Mw}}}{days})$ |
# | Gruenthal (Mw ≥ 6.5) | $e^{1.77 + \sqrt{0.037 + 1.02 \cdot Mw}}$ | $\frac{10^{2.8 + 0.024 \cdot Mw}}{days}$ |

# %% [markdown]
# ### 5) Compare the declustering results. Obtain the seismic parameters of the declustered catalogue.
#
# Create a table comparing the number and percentage of mainshocks, aftershocks and foreshocks detected by the two declustering methods selected and the seismic parameters for each of the declustered catalogues.

# %% [markdown]
# # Module 06 — Lecture Demo: Early Warning System Design
#
# **DIGIHAZ PhD Course** | Disaster Risk Reduction
#
# ---

# %% [markdown]
# ## Learning Objectives
#
# By the end of this session you will be able to:
#
# 1. Objective 1
# 2. Objective 2
# 3. Objective 3

# %%
# Setup
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Content
#
# *Lecture content goes here.*
